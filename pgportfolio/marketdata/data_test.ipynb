# %%
import pandas as pd

# %%
data = pd.read_csv('../../../../OneDrive - University of Edinburgh/Development/Adaptive_market_portfolio/data/processed/crsp_market_data_v2.csv')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_25740\2618822374.py:1: DtypeWarning: Columns (7,11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../../../../OneDrive - University of Edinburgh/Development/Adaptive_market_portfolio/data/processed/crsp_market_data_v2.csv')

# %%
data
# Out:
#           PERMNO        date  SHRCD TICKER                        COMNAM  \
# 0          61487  2003-12-29   11.0     AE  ADAMS RESOURCES & ENERGY INC
# 1          61487  2003-12-30   11.0     AE  ADAMS RESOURCES & ENERGY INC
# 2          61487  2003-12-31   11.0     AE  ADAMS RESOURCES & ENERGY INC
# 3          61487  2004-01-02   11.0     AE  ADAMS RESOURCES & ENERGY INC
# 4          61487  2004-01-05   11.0     AE  ADAMS RESOURCES & ENERGY INC
# ...          ...         ...    ...    ...                           ...
# 20831289   91453  2008-08-08   11.0    MAQ     MARATHON ACQUISITION CORP
# 20831290   91453  2008-08-11   11.0    MAQ     MARATHON ACQUISITION CORP
# 20831291   91453  2008-08-12   11.0    MAQ     MARATHON ACQUISITION CORP
# 20831292   91453  2008-08-13   11.0    MAQ     MARATHON ACQUISITION CORP
# 20831293   91453  2008-08-14   11.0    MAQ     MARATHON ACQUISITION CORP
#
#          TRDSTAT  PERMCO     CUSIP  DLSTCD  FACPR  ...    ASK   SHROUT  \
# ...

# %%
data.columns
# Out:
# Index(['PERMNO', 'date', 'SHRCD', 'TICKER', 'COMNAM', 'TRDSTAT', 'PERMCO',
#        'CUSIP', 'DLSTCD', 'FACPR', 'DLPRC', 'DLRET', 'PRC', 'VOL', 'RET',
#        'BID', 'ASK', 'SHROUT', 'CFACPR', 'CFACSHR', 'sprtrn', 'ABS_PRC',
#        'MidPrice', 'ADJ_ABS_PRC', 'MKTCAP', 'last_date'],
#       dtype='object')
